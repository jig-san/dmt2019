# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train_0.csv')
df_orig = pd.read_csv("training_set_VU_DM.csv", header=0, nrows=5000)

# %%
df.drop(['srch_id', 'click_bool',
       'gross_bookings_usd', 'booking_bool', 'position'], axis=1, inplace=True)
df_orig.drop(['srch_id', 'click_bool',
       'gross_bookings_usd', 'booking_bool', 'position'], axis=1, inplace=True)

# %%
b = list(set(df_orig.columns.values) - set(df.columns.values))

# %%
a = list(set(df.columns.values) - set(df_orig.columns.values))

# %%
sns.set(style="white")

corr = df_orig.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, cmap=cmap, vmax=.6, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr
# Out:
#                               srch_id   site_id  visitor_location_country_id  \
# srch_id                      1.000000 -0.090894                     0.079246
# site_id                     -0.090894  1.000000                    -0.284220
# visitor_location_country_id  0.079246 -0.284220                     1.000000
# visitor_hist_starrating     -0.201881  0.551227                    -0.325396
# visitor_hist_adr_usd        -0.163611  0.321947                    -0.588964
# prop_country_id              0.018978 -0.273833                     0.426034
# prop_id                      0.005563 -0.013381                     0.013765
# prop_starrating             -0.029127  0.060134                    -0.076165
# prop_review_score           -0.011513 -0.062347                     0.053497
# prop_brand_bool              0.057920 -0.178620                     0.188760
# prop_location_score1        -0.066948  0.176844                    -0.207602
# ...

# %%
columns = [
        'prop_location_score2',
        'prop_location_score1',
        'comp1_rate_percent_diff',
        'comp4_rate_percent_diff',
        'srch_booking_window',
        'price_usd',
        'visitor_hist_adr_usd',
        'gross_bookings_usd',
        'orig_destination_distance',
        ]
for col in columns: 
    cols = []
    cols.append(col)
    fig, axarr = plt.subplots(figsize=(1200/120, 300/120))
    df_orig[cols].boxplot(vert=False, sym='k.')
    plt.xscale('log')
    #vals = [x.dropna() for y,x in df_orig[cols].iteritems()]
    ax = sns.boxplot(df_orig[cols], orient='h', fliersize=2)
    ax.set_xscale('log')
    plt.xlim(xmin=1e-2)
    plt.xlim(xmax=1e+4)
    plt.subplots_adjust(left=0.3, bottom=0.1)
    ax.set_xlabel(col, fontsize=12)
    plt.show()
# Out:
# e:\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py:3215: MatplotlibDeprecationWarning:
# The `xmin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `left` instead.
#   alternative='`left`', obj_type='argument')
# e:\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py:3221: MatplotlibDeprecationWarning:
# The `xmax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `right` instead.
#   alternative='`right`', obj_type='argument')
# e:\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py:3215: MatplotlibDeprecationWarning:
# The `xmin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `left` instead.
#   alternative='`left`', obj_type='argument')
# e:\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py:3221: MatplotlibDeprecationWarning:
# ...
